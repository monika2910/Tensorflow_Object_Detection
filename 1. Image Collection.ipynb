# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\44785\monika_practice\tensorflow_object_detection\tfodcourse\tfod\lib\site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\44785\monika_practice\tensorflow_object_detection\tfodcourse\tfod\lib\site-packages (from opencv-python) (1.19.5)

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['thumbsup', 'thumbsdown', 'thankyou', 'hello']
number_imgs = 5

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(10)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(5)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for thumbsup
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting images for thumbsdown
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting images for thankyou
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting images for hello
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Requirement already satisfied: pyqt5 in c:\users\44785\monika_practice\tensorflow_object_detection\tfodcourse\tfod\lib\site-packages (5.15.4)
# Requirement already satisfied: lxml in c:\users\44785\monika_practice\tensorflow_object_detection\tfodcourse\tfod\lib\site-packages (4.6.3)
# Requirement already satisfied: PyQt5-Qt5>=5.15 in c:\users\44785\monika_practice\tensorflow_object_detection\tfodcourse\tfod\lib\site-packages (from pyqt5) (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in c:\users\44785\monika_practice\tensorflow_object_detection\tfodcourse\tfod\lib\site-packages (from pyqt5) (12.9.0)

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            0.13.0
# alabaster                          0.7.12
# alembic                            1.4.1
# anaconda-client                    1.8.0
# anaconda-navigator                 1.10.0
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.6.2
# astropy                            4.2.1
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# Automat                            20.2.0
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.9.3
# bitarray                           2.1.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.1
# blis                               0.2.4
# bokeh                              2.3.3
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# bs4                                0.0.1
# cached-property                    1.5.2
# cachetools                         4.2.2
# certifi                            2021.5.30
# cffi                               1.14.6
# chardet                            4.0.0
# ChatterBot                         1.0.5
# click                              8.0.1
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.10
# conda                              4.10.3
# conda-build                        3.21.5
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.4.7
# cycler                             0.10.0
# cymem                              2.0.3
# Cython                             0.29.24
# cytoolz                            0.11.0
# dask                               2021.7.0
# databricks-cli                     0.14.3
# decorator                          5.0.9
# defusedxml                         0.7.1
# distributed                        2021.7.0
# docker                             5.0.0
# docopt                             0.6.2
# docutils                           0.17.1
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# fastcache                          1.1.0
# filelock                           3.0.12
# Flask                              1.1.2
# Flask-Cors                         3.0.9
# flatbuffers                        1.12
# fsspec                             2021.7.0
# future                             0.18.2
# gast                               0.4.0
# gevent                             21.1.2
# gitdb                              4.0.7
# GitPython                          3.1.17
# glob2                              0.7
# google-auth                        1.34.0
# google-auth-oauthlib               0.4.5
# google-pasta                       0.2.0
# greenlet                           1.1.0
# grpcio                             1.34.1
# h5py                               3.1.0
# HeapDict                           1.0.1
# html5lib                           1.1
# hypothesis                         6.14.1
# idna                               2.10
# imagecodecs                        2021.6.8
# imageio                            2.9.0
# imagesize                          1.2.0
# imbalanced-learn                   0.7.0
# importlib-metadata                 3.10.0
# iniconfig                          1.1.1
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.9.2
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.17.0
# Jinja2                             2.11.3
# joblib                             1.0.1
# json5                              0.9.6
# jsonify                            0.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.6.1
# jupyterlab-widgets                 1.0.0
# Keras                              2.4.3
# keras-nightly                      2.5.0.dev2021032900
# Keras-Preprocessing                1.1.2
# keyring                            23.0.1
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.6.3
# Mako                               1.1.4
# Markdown                           3.3.4
# MarkupSafe                         2.0.1
# mathparse                          0.1.2
# matplotlib                         3.3.4
# mccabe                             0.6.1
# mediapipe                          0.8.7.2
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.1.1
# mkl-service                        2.3.0
# mlflow                             1.17.0
# mock                               4.0.3
# more-itertools                     8.8.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# murmurhash                         1.0.2
# mypy-extensions                    0.4.3
# mysql-connector-python             8.0.21
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.6.2
# nltk                               3.6.2
# nose                               1.3.7
# notebook                           6.2.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.21.1
# numpydoc                           1.1.0
# oauthlib                           3.1.1
# olefile                            0.46
# opencv-contrib-python              4.4.0.46
# opencv-python                      4.5.3.56
# openpyxl                           3.0.7
# opt-einsum                         3.3.0
# packaging                          21.0
# pandas                             1.2.4
# pandocfilters                      1.4.3
# parso                              0.8.2
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.7.0
# patsy                              0.5.1
# pep8                               1.7.1
# pickleshare                        0.7.5
# Pillow                             8.0.1
# Pint                               0.10.1
# pip                                21.1.3
# pipreqs                            0.4.10
# pkginfo                            1.7.1
# plac                               0.9.6
# plotly                             4.14.3
# pluggy                             0.13.1
# ply                                3.11
# preshed                            2.0.1
# prettytable                        2.0.0
# prometheus-client                  0.11.0
# prometheus-flask-exporter          0.18.2
# prompt-toolkit                     3.0.17
# protobuf                           3.17.3
# psutil                             5.8.0
# py                                 1.10.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.7.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycrypto                           2.6.1
# pycurl                             7.43.0.6
# pyerfa                             1.7.3
# pyflakes                           2.3.1
# Pygments                           2.9.0
# pylint                             2.9.3
# pymongo                            3.10.1
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# PyQt5                              5.15.4
# PyQt5-Qt5                          5.15.2
# PyQt5-sip                          12.9.0
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             6.2.4
# pytest-arraydiff                   0.3
# pytest-astropy                     0.8.0
# pytest-astropy-header              0.1.2
# pytest-doctestplus                 0.10.0
# pytest-openfiles                   0.5.0
# pytest-remotedata                  0.3.2
# python-dateutil                    2.8.2
# python-editor                      1.0.4
# python-sketch                      0.2.0
# pytz                               2021.1
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.4.1
# pyzmq                              18.0.0
# QtAwesome                          1.0.2
# qtconsole                          5.1.0
# QtPy                               1.9.0
# querystring-parser                 1.2.4
# regex                              2021.7.6
# requests                           2.25.1
# requests-oauthlib                  1.3.0
# retrying                           1.3.3
# rope                               0.19.0
# rsa                                4.7.2
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.1
# scikit-learn                       0.24.2
# scipy                              1.6.2
# seaborn                            0.11.1
# selenium                           3.141.0
# Send2Trash                         1.5.0
# setuptools                         52.0.0.post20210125
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# six                                1.16.0
# sketchify                          0.0.7
# smmap                              4.0.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# spacy                              2.1.9
# Sphinx                             4.0.2
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             3.3.6
# spyder-kernels                     0.5.1
# SQLAlchemy                         1.4.21
# sqlparse                           0.4.1
# srsly                              1.0.1
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tabulate                           0.8.9
# tblib                              1.7.0
# tensorboard                        2.5.0
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.0
# tensorflow                         2.5.0
# tensorflow-estimator               2.5.0
# termcolor                          1.1.0
# terminado                          0.9.4
# testpath                           0.5.0
# tf-slim                            1.1.0
# thinc                              7.0.8
# threadpoolctl                      2.2.0
# tifffile                           2021.4.8
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.51.0
# traitlets                          5.0.5
# typed-ast                          1.4.3
# typing-extensions                  3.10.0.0
# unicodecsv                         0.14.1
# urllib3                            1.26.6
# waitress                           2.0.0
# wasabi                             0.6.0
# wcwidth                            0.2.5
# webencodings                       0.5.1
# websocket-client                   1.1.0
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wordcloud                          1.8.1
# wrapt                              1.12.1
# xgboost                            0.90
# xlrd                               2.0.1
# XlsxWriter                         1.4.4
# xlwings                            0.24.3
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yarg                               0.1.9
# zict                               2.0.0
# zipp                               3.5.0
# zope.event                         4.5.0
# zope.interface                     5.4.0

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.3e39033b-2961-11ec-a5a8-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.3e39033b-2961-11ec-a5a8-d4d25291bb2a.xml.txt
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.5a7782b8-2963-11ec-8c19-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.5a7782b8-2963-11ec-8c19-d4d25291bb2a.xml.txt
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.c8331bc8-2961-11ec-b4e8-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.c8331bc8-2961-11ec-b4e8-d4d25291bb2a.xml.txt
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.c53151e0-2961-11ec-b6c4-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.c53151e0-2961-11ec-b6c4-d4d25291bb2a.xml.txt
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.ec551584-2962-11ec-b5a3-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.ec551584-2962-11ec-b5a3-d4d25291bb2a.xml.txt
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.3d356a7e-2963-11ec-8456-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.3d356a7e-2963-11ec-8456-d4d25291bb2a.xml.txt
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.23e2b409-2961-11ec-9755-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.23e2b409-2961-11ec-9755-d4d25291bb2a.xml.txt
# Cancel creation.
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.26ea8c16-2961-11ec-938b-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.26ea8c16-2961-11ec-938b-d4d25291bb2a.xml.txt
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.a7ff0970-2961-11ec-b210-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.a7ff0970-2961-11ec-b210-d4d25291bb2a.xml.txt
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.3d356a7e-2963-11ec-8456-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.3d356a7e-2963-11ec-8456-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.23e2b409-2961-11ec-9755-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.23e2b409-2961-11ec-9755-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.26ea8c16-2961-11ec-938b-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.26ea8c16-2961-11ec-938b-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.a7ff0970-2961-11ec-b210-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.a7ff0970-2961-11ec-b210-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\thankyou.b1013958-2961-11ec-b765-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou/thankyou.b1013958-2961-11ec-b765-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.3e39033b-2961-11ec-a5a8-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.3e39033b-2961-11ec-a5a8-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.5a7782b8-2963-11ec-8c19-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.5a7782b8-2963-11ec-8c19-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.c8331bc8-2961-11ec-b4e8-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.c8331bc8-2961-11ec-b4e8-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.c53151e0-2961-11ec-b6c4-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.c53151e0-2961-11ec-b6c4-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\hello\hello.ec551584-2962-11ec-b5a3-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/hello/hello.ec551584-2962-11ec-b5a3-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.0f7b39a8-2961-11ec-9415-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown/thumbsdown.0f7b39a8-2961-11ec-9415-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.2c0e9682-2963-11ec-8189-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown/thumbsdown.2c0e9682-2963-11ec-8189-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.230a4bc3-2963-11ec-89ec-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown/thumbsdown.230a4bc3-2963-11ec-89ec-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.9994f4d0-2961-11ec-9d43-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown/thumbsdown.9994f4d0-2961-11ec-9d43-d4d25291bb2a.xml
# Image:C:\Users\44785\Monika_Practice\Tensorflow_Object_Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\thumbsdown.b7b4760f-2962-11ec-8f17-d4d25291bb2a.jpg -> Annotation:C:/Users/44785/Monika_Practice/Tensorflow_Object_Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown/thumbsdown.b7b4760f-2962-11ec-8f17-d4d25291bb2a.xml

# %% [markdown]
# # 6. Move them into a Training and Testing Partition

# %% [markdown]
# # OPTIONAL - 7. Compress them for Colab Training

# %%
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
